# %%
# %pip install pandas numpy matplotlib scikit-learn

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv("./assets/canada_per_capita_income.csv")
df.head(2)
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935

# %%
# %matplotlib inline
# plt. xlabel( 'year')
# plt.ylabel( 'pci')
# plt.scatter(df.year, df['per capita income (US$)'], color='red', marker='+')

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['year']], df['per capita income (US$)'])
# Out:
# LinearRegression()

# %%
reg.predict([[2025]])
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/mlenv/lib/python3.9/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([45431.01947053])

# %%
reg.coef_
# Out:
# array([828.46507522])

# %%
reg.intercept_
# Out:
# -1632210.7578554575

# %%
# %matplotlib inline
plt.xlabel('year')
plt.ylabel('pci')
plt.scatter(df.year, df['per capita income (US$)'], color='red', marker='+')
plt.plot(df['year'], reg.predict(df[['year']]), color='blue')

# %%
# df2 = pd.read_csv("find_price.csv")
# df2

# %%
# p = reg.predict(df2)

# %%
# df2['price'] = p
# df2

# %%
# df2.to_csv("price_prediction.csv", index=False)

# %% [markdown]
# Exercise

# %%
import numpy as np
import matplotlib.pyplot as plt
# %pip install utils
from utils import *
import copy
import math
# %matplotlib inline
# Out:
# Collecting utils
#   Downloading utils-1.0.2.tar.gz (13 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: utils
#   Building wheel for utils (setup.py) ... done
#   Created wheel for utils: filename=utils-1.0.2-py2.py3-none-any.whl size=13950 sha256=ac78685ebe1db62e547cd3f2499a1e16cc0eab47acc7980043049c61ea8dfc08
#   Stored in directory: /Users/md.tajim/Library/Caches/pip/wheels/4c/a5/a3/ab48e06c936b39960801612ee2767ff53764119f33d3d646e7
# Successfully built utils
# Installing collected packages: utils
# Successfully installed utils-1.0.2
# Note: you may need to restart the kernel to use updated packages.

# %%
def sigmoid(z):
    """
    Compute the sigmoid of z

    Args:
        z (ndarray): A scalar, numpy array of any size.

    Returns:
        g (ndarray): sigmoid(z), with the same shape as z

    """

    ### START CODE HERE ###
    g = 1 / (1 + np.exp(-z))
    ### END SOLUTION ###

    return g

# %%
sigmoid(-1)
# Out:
# 0.2689414213699951
